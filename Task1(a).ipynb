# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.array([0, 10, 45, 70, 90, 100, 149, 180, 200, 250])
y = np.array([1, 3, 2, 5, 7, 8, 8, 9, 10, 12])
m=0
c=0
L=0.0000001
itrations=10000
n=len(x)
for i in range(itrations):
    Y_pred=m*x+c
    D_m=(-1/n)*sum(x)
    D_c=(-1/n)
    m=m-L*D_m
    c=c-L*D_c  
b=np.array([m,c])
print("Estimated coeffecients are : \n b[0]=",b[0]," b[1]=",b[1])
plt.scatter(x, y) 
plt.plot(x,Y_pred,color="b")   # my preddicted regression
plt.show()
# Out:
# Estimated coeffecients are :
#  b[0]= 0.10940000000000762  b[1]= 9.999999999998701e-05

# %%
x=np.array(range(1,101))
noise=np.random.normal(0,1,100)
y=np.add(x,noise)
#print(z)
m=0
c=0
L=0.000002
itrations=10000
n=len(x)
for i in range(itrations):
    Y_pred=m*x+c
    D_m=(-1/n)*sum(x)
    D_c=(-1/n)
    m=m-L*D_m
    c=c-L*D_c  
b=np.array([m,c])
print("Estimated coeffecients are : \n b[0]=",b[0]," b[1]=",b[1])
plt.scatter(x, y) 
plt.plot(x,Y_pred,color="g")   # my preddicted regression
plt.show()
# Out:
# Estimated coeffecients are :
#  b[0]= 1.0100000000001115  b[1]= 0.00019999999999997402
